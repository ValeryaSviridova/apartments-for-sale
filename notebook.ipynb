# %% [markdown]
# <div style="border:solid green 2px; padding: 20px">
#
# <b>Валерия, привет!</b> Мы рады тебя видеть на территории код-ревьюеров. Ты проделала большую работу над проектом, но давай познакомимся и сделаем его еще лучше! У нас тут своя атмосфера и несколько правил:
#
#
# 1. Меня зовут Александр Матвеевский. Я работаю код-ревьюером, моя основная цель — не указать на совершенные тобою ошибки, а поделиться своим опытом и помочь тебе стать аналитиком данных.
# 2. Общаемся на ты.
# 3. Если хочешь написать, спросить - не нужно стесняться. Только выбери свой цвет для комментария.
# 4. Это учебный проект, тут можно не бояться сделать ошибку.
# 5. У тебя неограниченное количество попыток для сдачи проекта.
# 6. Let's Go!
#
# ---
#
# Я буду красить комментарии цветом, пожалуйста, не удаляй их:
#
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
# Такой комментарий нужно исправить обязательно, он критически влияет на удачное выполнение проекта.
# </div>
#
# ---
#
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
#
# Такой комментарий является рекомендацией или советом. Можешь использовать их на своё усмотрение.
# </div>
#
# ---
#
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Такой комментарий  говорит о том, что было сделано что-то качественное и правильное =)
# </div>
#
# ---
#
# Предлагаю работать над проектом в диалоге: если ты что-то меняешь в проекте или отвечаешь на мои комментарии — пиши об этом. Мне будет легче отследить изменения, если ты выделишь свои комментарии:
#
# <div class="alert alert-info"> <b>Комментарии студента:</b> Например, вот так.</div>
#
# Всё это поможет выполнить повторную проверку твоего проекта оперативнее. Если будут какие-нибудь вопросы по моим комментариям, пиши, будем разбираться вместе :)
#
# ---

# %% [markdown]
# <h1>Исследовательский анализ данных<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Открытие-файла-с-данными-и-изучиние-общей-информации" data-toc-modified-id="Открытие-файла-с-данными-и-изучиние-общей-информации-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Открытие файла с данными и изучиние общей информации</a></span></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Предобработка данных</a></span><ul class="toc-item"><li><span><a href="#Работа-с-пропусками" data-toc-modified-id="Работа-с-пропусками-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Работа с пропусками</a></span><ul class="toc-item"><li><span><a href="#Обработка-floors_total,-locality_name,-balcony,-parks_around_3000,-ponds_around_3000" data-toc-modified-id="Обработка-floors_total,-locality_name,-balcony,-parks_around_3000,-ponds_around_3000-2.1.1"><span class="toc-item-num">2.1.1&nbsp;&nbsp;</span>Обработка floors_total, locality_name, balcony, parks_around_3000, ponds_around_3000</a></span></li><li><span><a href="#Обработка-locality_name,-parks_nearest,-ponds_nearest" data-toc-modified-id="Обработка-locality_name,-parks_nearest,-ponds_nearest-2.1.2"><span class="toc-item-num">2.1.2&nbsp;&nbsp;</span>Обработка locality_name, parks_nearest, ponds_nearest</a></span></li><li><span><a href="#Обработка-is_apartment" data-toc-modified-id="Обработка-is_apartment-2.1.3"><span class="toc-item-num">2.1.3&nbsp;&nbsp;</span>Обработка is_apartment</a></span></li><li><span><a href="#Обработка-airports_nearest,-citycenters_nearest" data-toc-modified-id="Обработка-airports_nearest,-citycenters_nearest-2.1.4"><span class="toc-item-num">2.1.4&nbsp;&nbsp;</span>Обработка airports_nearest, citycenters_nearest</a></span></li><li><span><a href="#Обработка-ceiling_height" data-toc-modified-id="Обработка-ceiling_height-2.1.5"><span class="toc-item-num">2.1.5&nbsp;&nbsp;</span>Обработка ceiling_height</a></span></li><li><span><a href="#Обработка-kitchen_area,-living_area" data-toc-modified-id="Обработка-kitchen_area,-living_area-2.1.6"><span class="toc-item-num">2.1.6&nbsp;&nbsp;</span>Обработка kitchen_area, living_area</a></span></li><li><span><a href="#Обработка-days_exposition" data-toc-modified-id="Обработка-days_exposition-2.1.7"><span class="toc-item-num">2.1.7&nbsp;&nbsp;</span>Обработка days_exposition</a></span></li></ul></li><li><span><a href="#Работа-с-типами-данных-в-каждом-столбце" data-toc-modified-id="Работа-с-типами-данных-в-каждом-столбце-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Работа с типами данных в каждом столбце</a></span></li><li><span><a href="#Обработка-аномальных-значений" data-toc-modified-id="Обработка-аномальных-значений-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Обработка аномальных значений</a></span><ul class="toc-item"><li><span><a href="#ceiling_height" data-toc-modified-id="ceiling_height-2.3.1"><span class="toc-item-num">2.3.1&nbsp;&nbsp;</span>ceiling_height</a></span></li><li><span><a href="#rooms" data-toc-modified-id="rooms-2.3.2"><span class="toc-item-num">2.3.2&nbsp;&nbsp;</span>rooms</a></span></li><li><span><a href="#total_area" data-toc-modified-id="total_area-2.3.3"><span class="toc-item-num">2.3.3&nbsp;&nbsp;</span>total_area</a></span></li><li><span><a href="#living_area" data-toc-modified-id="living_area-2.3.4"><span class="toc-item-num">2.3.4&nbsp;&nbsp;</span>living_area</a></span></li><li><span><a href="#kitchen_area" data-toc-modified-id="kitchen_area-2.3.5"><span class="toc-item-num">2.3.5&nbsp;&nbsp;</span>kitchen_area</a></span></li><li><span><a href="#last_price" data-toc-modified-id="last_price-2.3.6"><span class="toc-item-num">2.3.6&nbsp;&nbsp;</span>last_price</a></span></li></ul></li></ul></li><li><span><a href="#Добавление-в-таблицу-новых-столбцов" data-toc-modified-id="Добавление-в-таблицу-новых-столбцов-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Добавление в таблицу новых столбцов</a></span></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Анализ-основных-параметров" data-toc-modified-id="Анализ-основных-параметров-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Анализ основных параметров</a></span></li><li><span><a href="#Анализ-скорости-продажи-квартиры-days_exposition" data-toc-modified-id="Анализ-скорости-продажи-квартиры-days_exposition-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Анализ скорости продажи квартиры days_exposition</a></span></li><li><span><a href="#Анализ-средней-цены-одного-квадратного-метра-в-10-населённых-пунктах-с-наибольшим-числом-объявлений" data-toc-modified-id="Анализ-средней-цены-одного-квадратного-метра-в-10-населённых-пунктах-с-наибольшим-числом-объявлений-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Анализ средней цены одного квадратного метра в 10 населённых пунктах с наибольшим числом объявлений</a></span></li><li><span><a href="#Анализ-среднюю-цену-каждого-километра-в-Санкт-Петербурге" data-toc-modified-id="Анализ-среднюю-цену-каждого-километра-в-Санкт-Петербурге-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Анализ среднюю цену каждого километра в Санкт-Петербурге</a></span></li><li><span><a href="#Факторы-влияющие-на-общую-(полную)-стоимость-объекта" data-toc-modified-id="Факторы-влияющие-на-общую-(полную)-стоимость-объекта-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Факторы влияющие на общую (полную) стоимость объекта</a></span><ul class="toc-item"><li><span><a href="#total_area,-living_area,-kitchen_area" data-toc-modified-id="total_area,-living_area,-kitchen_area-4.5.1"><span class="toc-item-num">4.5.1&nbsp;&nbsp;</span>total_area, living_area, kitchen_area</a></span></li><li><span><a href="#floor" data-toc-modified-id="floor-4.5.2"><span class="toc-item-num">4.5.2&nbsp;&nbsp;</span>floor</a></span></li><li><span><a href="#rooms" data-toc-modified-id="rooms-4.5.3"><span class="toc-item-num">4.5.3&nbsp;&nbsp;</span>rooms</a></span></li><li><span><a href="#weekday,-month,-year" data-toc-modified-id="weekday,-month,-year-4.5.4"><span class="toc-item-num">4.5.4&nbsp;&nbsp;</span>weekday, month, year</a></span></li></ul></li></ul></li></ul></div>

# %% [markdown]
# В распоряжении данные сервиса Яндекс Недвижимость — архив объявлений за несколько лет о продаже квартир в Санкт-Петербурге и соседних населённых пунктах.
#
# Задача — выполнить предобработку данных и изучить их, чтобы найти интересные особенности и зависимости, которые существуют на рынке недвижимости.
#
# О каждой квартире в базе содержится два типа данных: добавленные пользователем и картографические. Например, к первому типу относятся площадь квартиры, её этаж и количество балконов, ко второму — расстояния до центра города, аэропорта и ближайшего парка.

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
#
# Отличная практика - расписывать цель и основные этапы своими словами (этот навык очень поможет на фильнальном проекте). Хорошо было бы добавить ход и цель исследования. Вот мой личный пример:
#
# ![image.png](attachment:image.png)
# </div>

# %% [markdown]
# Описание данных:
# - airports_nearest — расстояние до ближайшего аэропорта в метрах (м)
# - balcony — число балконов
# - ceiling_height — высота потолков (м)
# - cityCenters_nearest — расстояние до центра города (м)
# - days_exposition — сколько дней было размещено объявление (от публикации до снятия)
# - first_day_exposition — дата публикации
# - floor — этаж
# - floors_total — всего этажей в доме
# - is_apartment — апартаменты (булев тип)
# - kitchen_area — площадь кухни в квадратных метрах (м²)
# - last_price — цена на момент снятия с публикации
# - living_area — жилая площадь в квадратных метрах (м²)
# - locality_name — название населённого пункта
# - open_plan — свободная планировка (булев тип)
# - parks_around3000 — число парков в радиусе 3 км
# - parks_nearest — расстояние до ближайшего парка (м)
# - ponds_around3000 — число водоёмов в радиусе 3 км
# - ponds_nearest — расстояние до ближайшего водоёма (м)
# - rooms — число комнат
# - studio — квартира-студия (булев тип)
# - total_area — общая площадь квартиры в квадратных метрах (м²)
# - total_images — число фотографий квартиры в объявлении

# %% [markdown]
# <div class="alert alert-info"> <b>Большое спасибо за комментарии по улучшению проекта и полезные ссылки, постаралась все учесть:)</div>

# %% [markdown]
# ## Открытие файла с данными и изучиние общей информации

# %%
#импортируем библиотеки для дальнейшей работы
import pandas as pd
import matplotlib.pyplot as plt 
import numpy as np

# %%
#открытие документа
try:
    data = pd.read_csv('/datasets/real_estate_data.csv', sep='\t')
except:
    data = pd.read_csv('real_estate_data.csv', sep='\t')

#вывод первых 10 строчек датафрейма
data.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0  2019-03-07T00:00:00      3
# 1             7   3350000.0        40.4  2018-12-04T00:00:00      1
# 2            10   5196000.0        56.0  2015-08-20T00:00:00      2
# 3             0  64900000.0       159.0  2015-07-24T00:00:00      3
# 4             2  10000000.0       100.0  2018-06-19T00:00:00      2
#
#    ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 0            2.70          16.0         51.0      8          NaN  ...
# 1             NaN          11.0         18.6      1          NaN  ...
# 2             NaN           5.0         34.3      4          NaN  ...
# 3             NaN          14.0          NaN      9          NaN  ...
# 4            3.03          14.0         32.0     13          NaN  ...
#
#    kitchen_area  balcony    locality_name  airports_nearest  \
# 0          25.0      NaN  Санкт-Петербург           18863.0
# ...

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
#
# __Комментарий от ревьюера №1__
#
# Здорово, что для подгрузки данных используешь конструкцию `try-except`, она поможет избежать потенциальных ошибок при загрузке данных, связанных, например, с некорректным указанием путей.
#
# Подробнее о конструкции по ссылке:
#
# https://pythonworld.ru/tipy-dannyx-v-python/isklyucheniya-v-python-konstrukciya-try-except-dlya-obrabotki-isklyuchenij.html
#
# Либо же можно использовать стандартную библиотеку os:
#
# https://pythonworld.ru/moduli/modul-os.html
#
#
# Несколько интересных статей кейсы использования конструкции:
#
# https://www.programiz.com/python-programming/exception-handling
#
# https://towardsdatascience.com/do-not-abuse-try-except-in-python-d9b8ee59e23b
#
# https://www.techbeamers.com/use-try-except-python/
#
# Как вариант в try можно указать корректные пути (в нашем случае глобальные) в except - некорректные (локальные). Можно также специфицровать тип ошибки, FileNotFoundError или задать кастомный тип ошибки (FilePathError, например)
#
# Она полезна, если ты работаешь локально, а потом подгружаешь проект на платформу. Конструкция позволит не падать коду и локально, и на сервере ЯП, так как если не сработает один блок с путями, сработает другой.
#
# Ну и вообще, в целом полезно про эту констуркцию знать, она универсальна и может быть использована в разных задачах.

# %%
#вывод общей информацию о таблице
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        14504 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          2775 non-null   object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               12180 non-null  float64
#  14  locality_name         23650 non-null  object
# ...

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
# В последней или единственной строке кода Юпитера, метод print() не обязательно писать, в отличии от тренажера
# </div>

# %%
#вывод наименования столбцов
data.columns
# Out:
# Index(['total_images', 'last_price', 'total_area', 'first_day_exposition',
#        'rooms', 'ceiling_height', 'floors_total', 'living_area', 'floor',
#        'is_apartment', 'studio', 'open_plan', 'kitchen_area', 'balcony',
#        'locality_name', 'airports_nearest', 'cityCenters_nearest',
#        'parks_around3000', 'parks_nearest', 'ponds_around3000',
#        'ponds_nearest', 'days_exposition'],
#       dtype='object')

# %% [markdown]
# Переименуем столбцы cityCenters_nearest, ponds_around3000, parks_around3000

# %%
# переименование столбцов
data = data.rename(columns = {'cityCenters_nearest':'citycenters_nearest',
                            'ponds_around3000' : 'ponds_around_3000',
                            'parks_around3000' : 'parks_around_3000'})

# %%
#проверка явных дубликатов
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Проверка на дубликаты - основа предобработки данных
# </div>

# %% [markdown]
# Первичный анализ на основе имеющихся данных при помощи общей гистограммы

# %%
#Построение общей гистограммы для всех числовых столбцов таблицы.
data.hist(figsize=(15, 20))
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
# Такие предупреждения можно убрать 2 способами:
#
# 1. В конец кода добавить `plt.show()`, но для этого нужно вызвать библиотеку `matplotlib.pyplot as plt`
# 2. В конец кода добавить `;`
#
# ![image.png](attachment:image.png)
# </div>

# %% [markdown]
# **Вывод:** В данных отсутствуют явные дубликаты, но имеется большое кол-во пропусков, артефактов и некорректных типов значений. Перед анализом данных их необходимо обработать.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
# __Комментарий от ревьюера №1__
#
# Отлично! Первый взгляд на данные есть, план намечен.

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# ### Работа с пропусками

# %% [markdown]
# Проверка пропусков

# %%
data.isna().sum()
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height           9195
# floors_total               86
# living_area              1903
# floor                       0
# is_apartment            20924
# studio                      0
# open_plan                   0
# kitchen_area             2278
# balcony                 11519
# locality_name              49
# airports_nearest         5542
# citycenters_nearest      5519
# parks_around_3000        5518
# parks_nearest           15620
# ponds_around_3000        5518
# ponds_nearest           14589
# days_exposition          3181
# dtype: int64

# %%
pd.DataFrame(round(data.isna().mean()*100,)).style.background_gradient('coolwarm')
# Out:
# <style type="text/css">
# #T_b384c_row0_col0, #T_b384c_row1_col0, #T_b384c_row2_col0, #T_b384c_row3_col0, #T_b384c_row4_col0, #T_b384c_row6_col0, #T_b384c_row8_col0, #T_b384c_row10_col0, #T_b384c_row11_col0, #T_b384c_row14_col0 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_b384c_row5_col0 {
#   background-color: #cdd9ec;
#   color: #000000;
# }
# #T_b384c_row7_col0 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_b384c_row9_col0 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_b384c_row12_col0 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_b384c_row13_col0 {
#   background-color: #ead4c8;
#   color: #000000;
# }
# #T_b384c_row15_col0, #T_b384c_row16_col0, #T_b384c_row17_col0, #T_b384c_row19_col0 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_b384c_row18_col0 {
#   background-color: #f4987a;
#   color: #000000;
# }
# #T_b384c_row20_col0 {
#   background-color: #f7aa8c;
#   color: #000000;
# }
# ...

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Проверить колличество пропусков в % можно вот так:
#
#
#     pd.DataFrame(round(df.isna().mean()*100,)).style.background_gradient('coolwarm')

# %% [markdown]
# #### Обработка floors_total, locality_name, balcony, parks_around_3000, ponds_around_3000

# %% [markdown]
# - **Пропусков в floors_total и locality_name не так много, их природу логически сложно объяснить, можем не обрабатывать или заменить на 0**
# - **Заменим пропуски в balcony на 0, так как они, возможно, означают, что балкона просто нет**
# - **Пропуски в столбцах parks_around_3000 и ponds_around_3000 также могут означать, что парков и прудов просто нет в радиусе 3 км. Можно заменить на 0**

# %%
#заменяем пропуски на 0
data['floors_total'].fillna(0,inplace = True)
data['locality_name'].fillna(0,inplace = True)
data['balcony'].fillna(0,inplace = True)
data['parks_around_3000'].fillna(0,inplace = True)
data['ponds_around_3000'].fillna(0,inplace = True)

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Согласен, если пропуск - вероятнее всего балкон отсутствует

# %% [markdown]
# #### Обработка locality_name, parks_nearest, ponds_nearest

# %% [markdown]
# - **пропуски в parks_nearest, ponds_nearest можно попробовать заменить медианными значениями в зависимости от населенного пункта locality_name, но предварительно необходимо обработать текстовые значения в locality_name**

# %%
#Посмотрим уникальные значения в столбце locality_name и их количество.
print(data['locality_name'].unique())
#количество уникальных значений
print(len(data['locality_name'].unique()))
# Out:
# ['Санкт-Петербург' 'посёлок Шушары' 'городской посёлок Янино-1'
#  'посёлок Парголово' 'посёлок Мурино' 'Ломоносов' 'Сертолово' 'Петергоф'
#  'Пушкин' 'деревня Кудрово' 'Коммунар' 'Колпино'
#  'поселок городского типа Красный Бор' 'Гатчина' 'поселок Мурино'
#  'деревня Фёдоровское' 'Выборг' 'Кронштадт' 'Кировск'
#  'деревня Новое Девяткино' 'посёлок Металлострой'
#  'посёлок городского типа Лебяжье' 'посёлок городского типа Сиверский'
#  'поселок Молодцово' 'поселок городского типа Кузьмоловский'
#  'садовое товарищество Новая Ропша' 'Павловск' 'деревня Пикколово'
#  'Всеволожск' 'Волхов' 'Кингисепп' 'Приозерск' 'Сестрорецк'
#  'деревня Куттузи' 'посёлок Аннино' 'поселок городского типа Ефимовский'
#  'посёлок Плодовое' 'деревня Заклинье' 'поселок Торковичи'
#  'поселок Первомайское' 'Красное Село' 'посёлок Понтонный' 'Сясьстрой'
#  'деревня Старая' 'деревня Лесколово' 'посёлок Новый Свет' 'Сланцы'
#  'село Путилово' 'Ивангород' 'Мурино' 'Шлиссельбург' 'Никольское'
# ...

# %% [markdown]
# Дубликатов много, самый простой и быстрый вариант убрать типы населенных пунктов и остаивть только названия с помощью split, оставив только последнее слово в столбце.

# %%
#создадим новый столбец local c с помощью функции split() оставим только слово до первого пробела с конца
data['local'] = data['locality_name'].str.split().str[-1]
#посмотрим сколько осталось уникальных значений
len(data['local'].unique())
# Out:
# 295

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Отличный код

# %% [markdown]
# Количество уникальных значений сократилось на 1/4. Данные о ближайших парках и прудах можно не обрабатывать, так как для анализа нам не нужны эти столбцы, но можем заменить их медианными значениями, по типу населенного пункта.

# %%
#создаем два цикла, которые считают медианные значения в parks_nearest и ponds_nearest в зависимости от 
#названия населенного пункта

for t in data['local'].unique():
    data.loc[(data['local'] == t) & (data['parks_nearest'].isna()), 'parks_nearest'] = \
    data.loc[(data['local'] == t), 'parks_nearest'].median()

for t in data['local'].unique():
    data.loc[(data['local'] == t) & (data['ponds_nearest'].isna()), 'ponds_nearest'] = \
    data.loc[(data['local'] == t), 'ponds_nearest'].median()

# %% [markdown]
# Проверим результат работы

# %%
#считаем сумму пропусков по выбранным столбцам
print(data['parks_nearest'].isna().sum())
print(data['ponds_nearest'].isna().sum())
# Out:
# 6032
# 4962

# %% [markdown]
# Пропуски заметно уменьшились, но не все.
# Предположим, что оставшиеся пропуски в parks_nearest и ponds_nearest проставлены там, где у нас нет прудов и парков соответственно в радиусе 3км.
# Для этого посмотрим на кол-во строк, где parks_around_3000 = 0 и пропуск в parks_nearest. Аналогичную операцию проведем и над ponds_nearest.

# %%
data.loc[(data['parks_around_3000'] == 0) & (data['parks_nearest'].isna())]
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 1                 7   3350000.0       40.40  2018-12-04T00:00:00      1
# 5                10   2890000.0       30.40  2018-09-10T00:00:00      1
# 8                20   2900000.0       33.16  2018-05-23T00:00:00      1
# 12               10   3890000.0       54.00  2016-06-30T00:00:00      2
# 22               20   5000000.0       58.00  2017-04-24T00:00:00      2
# ...             ...         ...         ...                  ...    ...
# 23683            16   2100000.0       62.80  2018-09-18T00:00:00      4
# 23692             2   1350000.0       30.00  2017-07-07T00:00:00      1
# 23695            14   3100000.0       59.00  2018-01-15T00:00:00      3
# 23696            18   2500000.0       56.70  2018-02-11T00:00:00      2
# 23698             4   1350000.0       32.30  2017-07-21T00:00:00      1
#
#        ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# ...

# %%
data.loc[(data['ponds_around_3000'] == 0) & (data['ponds_nearest'].isna())]
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 5                10   2890000.0        30.4  2018-09-10T00:00:00      1
# 12               10   3890000.0        54.0  2016-06-30T00:00:00      2
# 22               20   5000000.0        58.0  2017-04-24T00:00:00      2
# 30               12   2200000.0        32.8  2018-02-19T00:00:00      1
# 37               10   1990000.0        45.8  2017-10-28T00:00:00      2
# ...             ...         ...         ...                  ...    ...
# 23683            16   2100000.0        62.8  2018-09-18T00:00:00      4
# 23692             2   1350000.0        30.0  2017-07-07T00:00:00      1
# 23695            14   3100000.0        59.0  2018-01-15T00:00:00      3
# 23696            18   2500000.0        56.7  2018-02-11T00:00:00      2
# 23698             4   1350000.0        32.3  2017-07-21T00:00:00      1
#
#        ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# ...

# %% [markdown]
# Итого строк 6032 и 4962 гипотеза подтвердилась. Можно пропуски заменить на 0.

# %%
data['parks_nearest'].fillna(0,inplace = True )
data['ponds_nearest'].fillna(0,inplace = True )

# %% [markdown]
# ####  Обработка is_apartment

# %% [markdown]
# - **Рассмотрим столбец is_apartment. Пропусков много, в отличии от идеального столбца studio. Возможно люди просто не знают что такое апартаменты и пропускали данные столбец. Отличие студий от апартаментов в том, что студия относится к жилому помещению в отличие от апартаментов. Можно заменить пропуски на False в тех случаях, где у студии стоит False .**

# %%
#используем логическое индексирование
data.loc[(data['studio'] == False) & (data['is_apartment'].isna()), 'is_apartment'] = False
#проверка отсутствия пропусков
data['is_apartment'].isna().sum()
# Out:
# 134

# %% [markdown]
# Осталось 134 пропуска, которые заменим на 0

# %%
data['is_apartment'].fillna(0,inplace = True )

# %% [markdown]
# ####  Обработка airports_nearest, citycenters_nearest

# %% [markdown]
# - **Разберемся с airports_nearest и citycenters_nearest. Посмотрим случаи, где citycenters_nearest у нас заполнен, а в airports_nearest пропуски**

# %%
data.loc[(data['citycenters_nearest'].notnull()) & (data['airports_nearest'].isna())]
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 733              18  18700000.0       109.7  2018-02-03T00:00:00      3
# 974               8  25897000.0       149.0  2018-03-26T00:00:00      4
# 2415             17   9500000.0        67.4  2017-04-15T00:00:00      2
# 7521             16  43500000.0       245.8  2015-12-17T00:00:00      3
# 7542             10   6900000.0        50.0  2016-03-17T00:00:00      1
# 8018             20  84000000.0       507.0  2015-12-17T00:00:00      5
# 8628              0   8000000.0        48.9  2018-02-23T00:00:00      1
# 9054              5  13000000.0        71.8  2017-09-12T00:00:00      2
# 9880             11   5300000.0        51.0  2018-01-10T00:00:00      2
# 10669             9   3400000.0        46.0  2018-09-01T00:00:00      2
# 11446             5   4000000.0        45.0  2016-09-07T00:00:00      2
# 11457             9  12900000.0        73.5  2017-09-12T00:00:00      2
# ...

# %% [markdown]
# Такие случаи у нас в Санк-Петербурге, их всего 24 строки, возможно такие пропуски означают, что квартира находится в самом центре, можно заменить на 1.
# Остальные пропуски возможно появились, потому что ни аэропорта, ни как такового центра в населенных пунктах нет. Можно не обрабатывать или заменить все на 0.

# %%
data.loc[(data['local'] == 'Санкт-Петербург') & (data['citycenters_nearest'].isna()), 'citycenters_nearest'] = \
    data.loc[(data['local'] == 'Санкт-Петербург'), 'citycenters_nearest'].fillna(1,inplace = True)

# %% [markdown]
# #### Обработка ceiling_height

# %% [markdown]
# - **ceiling_height можно заменить медианным значением столбца, возможно кто-то просто не знает высоту своих потолков и не посчитал важным указывать этот параметр в объявлении, заменим медианным значением по столбцу**

# %%
#замена при помощи fillna
data['ceiling_height'] = data['ceiling_height'].fillna(data['ceiling_height'].median())
#проверка отсутствия пропусков
data['ceiling_height'].isna().sum()
# Out:
# 0

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Некоторые столбцы можно поменять на значения, относительно своего района (например высота пололков). Вот так
#
#
# ![image.png](attachment:image.png)
#
# Если хочешь - дарю свой код =)
# </div>

# %% [markdown]
# #### Обработка kitchen_area, living_area

# %% [markdown]
# - **Возможно kitchen_area и living_area не указаны в студиях или апартаментах**

# %%
#посчитаем кол-во значений True, False в студиях и апартаментах
print(data['studio'].value_counts())
print(data['is_apartment'].value_counts())
# Out:
# False    23550
# True       149
# Name: studio, dtype: int64
# False    23649
# True        50
# Name: is_apartment, dtype: int64

# %% [markdown]
# Студий и апартаментов значительно меньше, чем пропусков в столбцах с площадями.
# Посмотрим сколько всего строк с пропусками и площади кухни и жилой площадей.

# %%
#вывод всех строк, где пропуски и в kitchen_area и в living_area
data.loc[(data['kitchen_area'].isna() & (data['living_area'].isna()))]
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 3                 0  64900000.0       159.0  2015-07-24T00:00:00      3
# 30               12   2200000.0        32.8  2018-02-19T00:00:00      1
# 37               10   1990000.0        45.8  2017-10-28T00:00:00      2
# 44               13   5350000.0        40.0  2018-11-18T00:00:00      1
# 59               15   6300000.0        46.5  2017-03-06T00:00:00      1
# ...             ...         ...         ...                  ...    ...
# 23632            20   5000000.0        38.0  2018-06-23T00:00:00      1
# 23642            14   5950000.0        80.3  2018-07-03T00:00:00      3
# 23663            12   6400000.0        88.0  2018-01-12T00:00:00      4
# 23670             9   2450000.0        45.6  2018-02-08T00:00:00      1
# 23679             0   2500000.0        35.0  2017-12-08T00:00:00      1
#
#        ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# ...

# %% [markdown]
# В подавляющем большинстве, если в объявлении пропущена жилая площадь, то в ней будет пропущена и площадь кухни. Логического объяснения таким пропускам не находится. С помощью математических вычислений заполним пропуски, где это возможно, вычитая из total_area поочередно кухню, чтобы узнать примерный размер жилой площади и наоборот.

# %%
#с помощью логической индексации выбираем строки с пропусками и заполняем их разницей
data.loc[data['kitchen_area'].isna(), 'kitchen_area'] = data.loc[data['kitchen_area'].isna(), 'kitchen_area'] - data.loc[data['kitchen_area'].isna(), 'living_area']
data.loc[data['living_area'].isna(), 'living_area'] = data.loc[data['living_area'].isna(), 'total_area'] - data.loc[data['living_area'].isna(), 'kitchen_area']

# %%
#считаем кол-во пропусков
print(data['kitchen_area'].isna().sum())
print(data['living_area'].isna().sum())
# Out:
# 2278
# 1464

# %% [markdown]
# Операции над площадью кухни не дали результатов, пропуски жилой площади немного получилось заполнить. Можно попробовать оставшиеся пропуски заполнить медианным значением в зависимости от кол-ва комнат('rooms').

# %%
#цикл проходит по уникальным значениям кол-ва комнат, считает медианное значение кухни и заполняет им пропуски
for t in data['rooms'].unique():
    data.loc[(data['rooms'] == t) & (data['kitchen_area'].isna()), 'kitchen_area'] = \
    data.loc[(data['rooms'] == t), 'kitchen_area'].median()  

for t in data['rooms'].unique():
    data.loc[(data['rooms'] == t) & (data['living_area'].isna()), 'living_area'] = \
    data.loc[(data['rooms'] == t), 'living_area'].median()

# %%
#считаем суммы пропусков
print(data['kitchen_area'].isna().sum())
print(data['living_area'].isna().sum())
# Out:
# 197
# 0

# %% [markdown]
# Пропуски в жилой площади устранены, пропусков в кухне осталось незначительно число, изменим их на 0.

# %%
data['kitchen_area'].fillna(0,inplace = True)
data['kitchen_area'].isna().sum()
# Out:
# 0

# %% [markdown]
# #### Обработка days_exposition

# %% [markdown]
# Возможно пропуски стоят, потому что квартира еще не продана, заменим их на 0 и будем учитывать это в дальнейшей проработке.

# %%
data['days_exposition'].fillna(0,inplace = True)

# %%
#итоговая проверка пропусков всего датафрейма
data.isna().sum()
# Out:
# total_images               0
# last_price                 0
# total_area                 0
# first_day_exposition       0
# rooms                      0
# ceiling_height             0
# floors_total               0
# living_area                0
# floor                      0
# is_apartment               0
# studio                     0
# open_plan                  0
# kitchen_area               0
# balcony                    0
# locality_name              0
# airports_nearest        5542
# citycenters_nearest     5519
# parks_around_3000          0
# parks_nearest              0
# ponds_around_3000          0
# ponds_nearest              0
# days_exposition            0
# local                     49
# dtype: int64

# %% [markdown]
# Пробуски в инстересующих нас столбцах обработаны.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Пропуски обработаны корректно
# </div>

# %% [markdown]
# ### Работа с типами данных в каждом столбце

# %%
#вывод общей информацию о таблице
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 23 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        23699 non-null  float64
#  6   floors_total          23699 non-null  float64
#  7   living_area           23699 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          23699 non-null  object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          23699 non-null  float64
#  13  balcony               23699 non-null  float64
#  14  locality_name         23699 non-null  object
# ...

# %% [markdown]
# Некорректные типы данных в следующих столбцах:
# - is_apartment необходимо заменить на булевое значение, тк у нас в этом столбце хранятся только True или False
# - floors_total число этажей также должно быть целым значением
# - parks_around_3000 и ponds_around_3000 отражают кол-во парков и прудов, эти числа не могут быть вещественными
# - balcony кол-во балконом должно быть целым
# - days_exposition дни также не могут быть не целым числом
# - first_day_exposition необходимо преобразовать в формат даты

# %%
#изменим типы данных 
data['is_apartment'] = data['is_apartment'].astype('bool')
data['floors_total'] = data['floors_total'].astype('int')
data['parks_around_3000'] = data['parks_around_3000'].astype('int')
data['ponds_around_3000'] = data['ponds_around_3000'].astype('int')
data['balcony'] = data['balcony'].astype('int')
#data['days_exposition'] = data['days_exposition'].astype('int') (мы не можем преобразовать потому что содержит nan)
data['first_day_exposition'] = pd.to_datetime(data['first_day_exposition'],format = '%Y-%m-%dT%H:%M:%S')
data['last_price'] = data['last_price'].astype('int')

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
# __Комментарий от ревьюера №1__
#
# Давай посмотрим на столбец `last_price`, он имеет дробный тип данных. Но ведь никто не продаёт недвижку с копейками. Что думаешь?
# </div>

# %% [markdown]
# Данныев датафрейме приведены к соответствующим корректным типам.

# %% [markdown]
# ### Обработка аномальных значений

# %%
#числовое опсание данных во всех числовых колонках
data.describe()
# Out:
#        total_images    last_price    total_area         rooms  ceiling_height  \
# count  23699.000000  2.369900e+04  23699.000000  23699.000000    23699.000000
# mean       9.858475  6.541549e+06     60.348651      2.070636        2.724358
# std        5.682529  1.088701e+07     35.654083      1.078405        0.988298
# min        0.000000  1.219000e+04     12.000000      0.000000        1.000000
# 25%        6.000000  3.400000e+06     40.000000      1.000000        2.600000
# 50%        9.000000  4.650000e+06     52.000000      2.000000        2.650000
# 75%       14.000000  6.800000e+06     69.900000      3.000000        2.700000
# max       50.000000  7.630000e+08    900.000000     19.000000      100.000000
#
#        floors_total   living_area         floor  kitchen_area       balcony  \
# count  23699.000000  23699.000000  23699.000000  23699.000000  23699.000000
# mean      10.635090     34.780644      5.892358     10.377514      0.591080
# ...

# %% [markdown]
# Наблюдаем аномальные значения в столбце:
# - ceiling_height (можно ограничения поставить в соответствии минимальная высота потолка определяется СНиП как 2,5 м., в пентхаусах высота потолка может достигать 12 метров)
# - total_area
# - rooms
# - living_area
# - kitchen_area
# - last_price
# - days_exposition
# В значениях данных столбцов большой разрыв между max/q3, на них стоит обратить внимание.

# %% [markdown]
# Для наглядности разберемся с каждым столбцом с аномалией отдельно. Посмотрим диаграммы размахов и в соответствии с ними отбросим значения по верхнему краю.

# %% [markdown]
# #### ceiling_height

# %% [markdown]
# Минимально допустимая высота потолка по нормам 2.5м, в пентхаусах высота потолка может достигать 12 метров, ограничимся этими цифрами.

# %%
#срез ввиду ограничений потолка 
data = data.query('ceiling_height >= 2.5 & ceiling_height <=12')
data['ceiling_height'].describe()
# Out:
# count    23602.000000
# mean         2.699217
# std          0.236539
# min          2.500000
# 25%          2.600000
# 50%          2.650000
# 75%          2.700000
# max         10.300000
# Name: ceiling_height, dtype: float64

# %% [markdown]
# #### rooms

# %%
#диаграмма размаха
data.boxplot('rooms')
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Здорово, что  проверяешь данные не "на глаз". Лучше посмотреть на выбросы и аномалии данных математически, и удалить их с помощью специального метода boxplot()

# %% [markdown]
# Верхняя граница проходит по 6 комнатам, ограним датафрейм 6ю комнатами

# %%
data = data.query('rooms <= 6')
data['rooms'].describe()
# Out:
# count    23512.000000
# mean         2.048146
# std          1.007426
# min          0.000000
# 25%          1.000000
# 50%          2.000000
# 75%          3.000000
# max          6.000000
# Name: rooms, dtype: float64

# %% [markdown]
# #### total_area

# %%
data.boxplot('total_area', fontsize=10)
plt.show()

# %%
data = data.query('total_area <= 130')
data['total_area'].describe()
# Out:
# count    22761.000000
# mean        55.566963
# std         21.169346
# min         12.000000
# 25%         39.900000
# 50%         51.000000
# 75%         67.000000
# max        130.000000
# Name: total_area, dtype: float64

# %% [markdown]
# #### living_area

# %%
data.boxplot('living_area', fontsize=10)
plt.show()

# %%
data = data.query('living_area <= 75')
data['living_area'].describe()
# Out:
# count    22497.000000
# mean        31.374684
# std         13.586067
# min          2.000000
# 25%         18.200000
# 50%         30.000000
# 75%         41.000000
# max         75.000000
# Name: living_area, dtype: float64

# %% [markdown]
# #### kitchen_area

# %%
data.boxplot('kitchen_area', fontsize=10)
plt.show()

# %%
data = data.query('kitchen_area <= 16')
data['kitchen_area'].describe()
# Out:
# count    21118.000000
# mean         9.043203
# std          2.707969
# min          0.000000
# 25%          7.000000
# 50%          9.000000
# 75%         10.700000
# max         16.000000
# Name: kitchen_area, dtype: float64

# %% [markdown]
# #### last_price

# %%
data.boxplot('last_price', fontsize=10)
plt.show()

# %%
data = data.query('last_price <= 10000000')
data['last_price'].describe()
# Out:
# count    2.002000e+04
# mean     4.560693e+06
# std      1.912922e+06
# min      4.300000e+05
# 25%      3.250000e+06
# 50%      4.290000e+06
# 75%      5.650000e+06
# max      1.000000e+07
# Name: last_price, dtype: float64

# %%
# проверим не появились ли пропуски
data.isna().sum()
# Out:
# total_images               0
# last_price                 0
# total_area                 0
# first_day_exposition       0
# rooms                      0
# ceiling_height             0
# floors_total               0
# living_area                0
# floor                      0
# is_apartment               0
# studio                     0
# open_plan                  0
# kitchen_area               0
# balcony                    0
# locality_name              0
# airports_nearest        5264
# citycenters_nearest     5252
# parks_around_3000          0
# parks_nearest              0
# ponds_around_3000          0
# ponds_nearest              0
# days_exposition            0
# local                     37
# dtype: int64

# %%
data.describe()
# Out:
#        total_images    last_price    total_area         rooms  ceiling_height  \
# count  20020.000000  2.002000e+04  20020.000000  20020.000000    20020.000000
# mean       9.625075  4.560693e+06     51.088299      1.881469        2.664984
# std        5.491188  1.912922e+06     16.528595      0.879177        0.192529
# min        0.000000  4.300000e+05     12.000000      0.000000        2.500000
# 25%        6.000000  3.250000e+06     38.100000      1.000000        2.600000
# 50%        9.000000  4.290000e+06     47.300000      2.000000        2.650000
# 75%       13.000000  5.650000e+06     61.000000      3.000000        2.650000
# max       39.000000  1.000000e+07    125.700000      6.000000       10.300000
#
#        floors_total   living_area         floor  kitchen_area       balcony  \
# count  20020.000000  20020.000000  20020.000000  20020.000000  20020.000000
# mean      10.647952     29.719938      5.832368      8.878834      0.583616
# ...

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №2__
#
# Можно вот так:
#
#     # функция для подсчёта границ с учетом 1.5 размаха
#     def quartile_range(data, column):
#         q1 = data[column].quantile(0.25)
#         q3 = data[column].quantile(0.75)
#         iqr = q3 - q1
#         dfq = data.loc[(data[column] < q3 + 1.5*iqr) & (data[column] > q1 - 1.5*iqr), column]
#         return dfq
#     # столбцы с выбросами
#     list_features = ['last_price', 'total_area', 'kitchen_area', 'living_area', 'days_exposition', 'ceiling_height']
#     for col in list_features:
#         data[col] = quartile_range(data, col)

# %% [markdown]
# **Вывод:** Данные успешно обработаны, можно приступать к созданию вспомогательных столбцов для последующего анализа.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Второй раздел сделан хорошо. Проверены основные возможные проблемы в данных.

# %% [markdown]
# ## Добавление в таблицу новых столбцов

# %% [markdown]
# - **Добавим месяц публикации объявления.**

# %%
#используем класс DatetimeIndex и его атрибут month, чтобы вывести номер месяца
data['month'] = pd.DatetimeIndex(data['first_day_exposition']).month
#выведим только 2 столбца, чтобы проверить корректность
data[['first_day_exposition','month']].head()
# Out:
#   first_day_exposition  month
# 1           2018-12-04     12
# 2           2015-08-20      8
# 5           2018-09-10      9
# 6           2017-11-02     11
# 8           2018-05-23      5

# %% [markdown]
# - **Добавим год публикации объявления**

# %%
#используем класс DatetimeIndex и его атрибут month, чтобы вывести номер месяца
data['year'] = pd.DatetimeIndex(data['first_day_exposition']).year 
#выведим только 2 столбца, чтобы проверить корректность
data[['first_day_exposition','year']].head()
# Out:
#   first_day_exposition  year
# 1           2018-12-04  2018
# 2           2015-08-20  2015
# 5           2018-09-10  2018
# 6           2017-11-02  2017
# 8           2018-05-23  2018

# %% [markdown]
# - **Добавим день недели публикации объявления (0 — понедельник, 1 — вторник и так далее)**

# %%
#используем свойство dt.dayofweek
data['weekday'] = data['first_day_exposition'].dt.dayofweek
data[['first_day_exposition','weekday']].head()
# Out:
#   first_day_exposition  weekday
# 1           2018-12-04        1
# 2           2015-08-20        3
# 5           2018-09-10        0
# 6           2017-11-02        3
# 8           2018-05-23        2

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
# Совет на будущие работы: обычно в датафреймах содержатся данные за несколько лет. Важно выбрать корректный метод для вычленения месяца, иначе месяца разных годов могут стать одним месяцем. Обрати внимание на метод astype('datetime64[M]'). Для его использования не нужно обращаться к pd.DatetimeIndex.
#
# Вот хорошая статья на этот счёт:
#
#     https://pythobyte.com/how-to-work-with-dates-and-times-in-python-0a176355/
#
#     и
#
#     https://stackoverflow.com/questions/70901855/get-hour-and-minutes-and-seconds-from-numpy-datetime64
# </div>

# %% [markdown]
# - **Добавим тип этажа квартиры (значения — «первый», «последний», «другой»)**

# %% [markdown]
# Для получаения такого столбца обратимся к категоризации данных, для этого нам необходимы два столбца floor и
# floors_total. Создадим функцию, которая будет перебирать значения по вертикали и в зависимости от результата присваивать категорию.

# %%
def categorize_floor(array):
    if array['floor'] == 1:
        return 'первый'
    elif array['floor'] == array['floors_total']:
        return 'последний'
    else:
        return 'другой'
    
#альтернативный способ aparts['level'] = np.where(aparts['floor'] == 1, 'первый', 'другой') с помощью библиотеки numpy    

#вызовем функцию для создания нового столбца
data['category_floor_of_flat'] = data.apply(categorize_floor, axis = 1)  

data[['floor','floors_total', 'category_floor_of_flat']].head()
# Out:
#    floor  floors_total category_floor_of_flat
# 1      1            11                 первый
# 2      4             5                 другой
# 5      5            12                 другой
# 6      6            26                 другой
# 8     26            27                 другой

# %% [markdown]
# - **Добавим цену одного квадратного метра**

# %%
#делим цену на общую площадь
data['price_per_meter'] = data['last_price']/data['total_area']
data[['total_area','last_price','price_per_meter']].head()
# Out:
#    total_area  last_price  price_per_meter
# 1       40.40     3350000     82920.792079
# 2       56.00     5196000     92785.714286
# 5       30.40     2890000     95065.789474
# 6       37.30     3700000     99195.710456
# 8       33.16     2900000     87454.764777

# %% [markdown]
# - **Добавим расстояние до центра города в километрах (переведите из м в км и округлите до целых значений)**

# %%
#делим значения в столбце citycenters_nearest в метрах на 1000, чтобы перевести в км
data['citycenters_nearest_km'] = data['citycenters_nearest']/1000 
data[['citycenters_nearest','citycenters_nearest_km']].head()
# Out:
#    citycenters_nearest  citycenters_nearest_km
# 1              18603.0                  18.603
# 2              13933.0                  13.933
# 5                  NaN                     NaN
# 6              19143.0                  19.143
# 8                  NaN                     NaN

# %%
#для округления импортируем библиотеку numpy
import numpy as np
data['citycenters_nearest_km'] = np.round(data['citycenters_nearest_km'])                     
data[['citycenters_nearest','citycenters_nearest_km']].head()
# Out:
#    citycenters_nearest  citycenters_nearest_km
# 1              18603.0                    19.0
# 2              13933.0                    14.0
# 5                  NaN                     NaN
# 6              19143.0                    19.0
# 8                  NaN                     NaN

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Этот раздел выполнен качественно
# </div>

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# ### Анализ основных параметров

# %% [markdown]
# Гистограммы
# - общая площадь;
# - жилая площадь;
# - площадь кухни;
# - цена объекта;
# - количество комнат;
# - высота потолков;
# - этаж квартиры;
# - тип этажа квартиры («первый», «последний», «другой»);
# - общее количество этажей в доме;
# - расстояние до центра города в метрах;
# - расстояние до ближайшего аэропорта;
# - расстояние до ближайшего парка;
# - день и месяц публикации объявления.
#
#
#
# Построим отдельные гистограммы для каждого из этих параметров.

# %%
#список с наименованием столбцов, по которым мы хотим построить гистограмму
columns_for_hist = ['living_area','total_area','kitchen_area','last_price','rooms','ceiling_height',
                       'floor', 'category_floor_of_flat', 'floors_total','first_day_exposition',
                    'citycenters_nearest','airports_nearest','parks_nearest', 'days_exposition', 'weekday', 'month']

# %%
#ф-я которая проходит по всем столбцам из созданного списка выше и создает на основе их значений гистограммы
def data_hist(data,columns_for_hist):
    for column in columns_for_hist:
        data[column].hist(bins = 15, figsize = (15,5))
        plt.title(column)
        plt.show()
        print()

# %%
data_hist(data,columns_for_hist)
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Здорво, что используешь собственные функции
# </div>

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
# Нет решения по дню недели / месяцу года. Поправь, пожалуйста
# </div>

# %% [markdown]
# **Выводы:**

# %% [markdown]
# Самое большое кол-во объявлений у квартир со следующими параметрами:
# - общая площадь от 35 до 60 кв м
# - цена от 3000000 до 5000000
# - кухня от 6 до 10м
# - 1/2/3 комнатная
# - потолки от 2.5 до 3м
# - квартира находится на 1-4 этаже в 9-этажке
# - пик объявлений о продаже был на стыже 2017 и 2018 годах
# - 10-17 км до центра города

# %% [markdown]
# ### Анализ скорости продажи квартиры days_exposition

# %%
data.boxplot('days_exposition')
plt.show()

# %% [markdown]
# Наблюдаем выбросы по верхней линии выше 450. Исключим эти значения и значения равные 0 (ранее пропуски, отметили, что возможно такие квартиры еще не проданы)

# %%
# Гистограма времени продаж
plt.hist(data.query('days_exposition != 0 & days_exposition < 450')['days_exposition'], bins=100)
plt.title('Время продажи')
plt.xlabel('Дни')
plt.ylabel('Количество квартир')
plt.show()

print(data.query('days_exposition != 0 & days_exposition < 450')['days_exposition'].describe())
# Out:
# count    16040.000000
# mean       116.191958
# std        107.772652
# min          1.000000
# 25%         38.000000
# 50%         75.000000
# 75%        167.000000
# max        449.000000
# Name: days_exposition, dtype: float64

# %% [markdown]
# **Вывод:** Большая часть квартир были проданы в промежутке от 0 до 100 дней с момента выставления объявления.
# Квартиры проданные меньше, чем за 75 дней относятся к быстрым продажам, если объявление висело более 167 продажа относится к долгой и встречается реже. Также продажа некоторых квартир достигала до 449 дней, что аномально долги, возможно это какой-то выброс.
#
# Медиана: 75
#
# Среднее значение: 116

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
# Немного не так, чтобы ответить на вопрос "Какие продажи можно считать быстрыми, а какие — необычно долгими?" лучше посмотреть на распределение данные с помощью boxplot() или describe().
# </div>

# %% [markdown]
# ### Анализ средней цены одного квадратного метра в 10 населённых пунктах с наибольшим числом объявлений

# %%
#вывод топ городов по объявлениям
top_city = data['local'].value_counts().head(10)
top_city
# Out:
# Санкт-Петербург    12479
# Мурино               565
# Кудрово              428
# Шушары               427
# Всеволожск           377
# Колпино              321
# Пушкин               310
# Парголово            310
# Гатчина              297
# Выборг               218
# Name: local, dtype: int64

# %%
#строим сводную таблицу, учитывая cрез городов в top_city.index
data_pivot = (data.query('local in @top_city.index').pivot_table(index='local', 
                                                                 values='price_per_meter', aggfunc='median'))
data_pivot.index.names = ['Топ городов по кол-ву объявлений'] #переименовываем первый столбец-индекс
data_pivot.columns = data_pivot.columns.get_level_values(0) #сбрасываем мультииндекс
data_pivot.rename(columns={'price_per_meter':'средняя цена за кв м'}, inplace=True) #переименовываем столбцы
data_pivot.sort_values('средняя цена за кв м') #сортируем по столбцу 'price_per_meter'
# Out:
#                                   средняя цена за кв м
# Топ городов по кол-ву объявлений
# Выборг                                    58133.213989
# Всеволожск                                65540.540541
# Гатчина                                   67695.961995
# Колпино                                   74722.222222
# Шушары                                    76829.268293
# Мурино                                    86351.351351
# Парголово                                 92294.871795
# Кудрово                                   96052.631579
# Пушкин                                    97607.845631
# Санкт-Петербург                          101190.476190

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
# Таблица верна. Совет: на общие продажи лучше смотреть через призму медианы. Она более устойчива к выбросам
# </div>

# %% [markdown]
# **Вывод:** Дороже всего в Санкт-Петербурге (в среднем 101190 р за кв м), дешевле в Выборге(58133р за кв м) из самых популярных городов с объявлениями по продаже недвижимости.

# %% [markdown]
# ### Анализ среднюю цену каждого километра в Санкт-Петербурге

# %%
#citycenters_nearest_km расстояние до цента в км
data_pivot = (data.query('local=="Санкт-Петербург"').pivot_table(index='citycenters_nearest_km', 
                                                                 values=['last_price'], aggfunc='median'))
data_pivot.index.names = ['км'] #переименовываем первый столбец-индекс
data_pivot.columns = data_pivot.columns.get_level_values(0) #сбрасываем мультииндекс
data_pivot.rename(columns={'last_price':'средняя цена'}, inplace=True) #переименовываем столбцы
#data_pivot.sort_values('средняя цена за кв м') #сортируем по столбцу 'price_per_meter'
data_pivot
# Out:
#       средняя цена
# км
# 0.0      7200000.0
# 1.0      7985000.0
# 2.0      7500000.0
# 3.0      6700000.0
# 4.0      6912500.0
# 5.0      6950000.0
# 6.0      6500000.0
# 7.0      6000000.0
# 8.0      5866269.5
# 9.0      4800000.0
# 10.0     4725000.0
# 11.0     4750000.0
# 12.0     4760000.0
# 13.0     4990000.0
# 14.0     4700000.0
# 15.0     4700000.0
# 16.0     4600000.0
# 17.0     4490000.0
# 18.0     4200000.0
# 19.0     4474500.0
# 20.0     4825000.0
# 21.0     5113550.0
# 22.0     4800000.0
# 23.0     4370000.0
# 24.0     3480000.0
# 25.0     3684881.0
# 26.0     3310000.0
# 27.0     2250000.0
# 28.0     4990000.0
# 29.0     4535000.0

# %%
data_pivot.plot(y = "средняя цена",kind = 'bar', figsize = (20,10), title = 'Cредняя цена квартиры за каждый км отдаления от центра')
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Отличная визуализация. В твой код добавил заголовок, посмотри, пожалуйста, этот момент. Очень важно оформлять графики
# </div>

# %% [markdown]
# Ожидаемо, что в радиусе 1 км центра самые высокие показатели, заметные уменьшения начинаются с дальности в 9км, но и дальше распределение очень мягкое. возможно причина в том, что многие достопримечательности находятся не только в центре города и возле них цены на квартиры также высокие.

# %% [markdown]
# ###  Факторы влияющие на общую (полную) стоимость объекта

# %% [markdown]
# Какие факторы больше всего влияют на общую (полную) стоимость объекта? (last_price)
# Изучим, зависит ли цена от:
# - общей площади;total_area
# - жилой площади;living_area
# - площади кухни;kitchen_area
# - количества комнат;kitchen_area
# - этажа, на котором расположена квартира (первый, последний, другой);
# - даты размещения (день недели, месяц, год).

# %% [markdown]
# #### total_area, living_area, kitchen_area

# %%
#корреляцией Пирсона 
print(data[['total_area','living_area','kitchen_area']].corr())
pd.plotting.scatter_matrix(data[['total_area','living_area','kitchen_area']],figsize=(10,10))
plt.show()
# Out:
#               total_area  living_area  kitchen_area
# total_area      1.000000     0.902530      0.379413
# living_area     0.902530     1.000000      0.126607
# kitchen_area    0.379413     0.126607      1.000000

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
# Немного не так, зависимость нелинейных данных (в нашем случае это площади) рассматриваются через тип графика scatter. Поправишь, пожалуйста, этот момент в разделе?
#
# ---
#
# Так же графики зависимостей лучше подкрепить корреляцией Пирсона и сразу интерпретировать полученные данные
# </div>

# %% [markdown]
# **Вывод:** При увеличеснии жилой площади, цена квартиры растет. Корреляция этих параметров крайне высокая.При увеличении площади кухни и общей площади также соответственно увеличивается и стоимость в среднем. Но корреляция не слишком высокая. То есть самую сильную зависимость показывает параметр жилой площади.

# %% [markdown]
# #### floor

# %%
#медиана цены за квартиру в зависимости от категории этажа
data_pivot = data.pivot_table(index='category_floor_of_flat', values='last_price')
data_pivot.index.names = ['тип этажа'] #переименовываем первый столбец-индекс
data_pivot.columns = data_pivot.columns.get_level_values(0) #сбрасываем мультииндекс
data_pivot.rename(columns={'last_price':'средняя цена'}, inplace=True) #переименовываем столбцы
data_pivot
# Out:
#            средняя цена
# тип этажа
# другой     4.746270e+06
# первый     3.965755e+06
# последний  4.150062e+06

# %%
data_pivot.plot( y = 'средняя цена',kind = 'bar', figsize = (5,5), title = 'зависимость цены от этажа')
plt.show()

# %% [markdown]
# **Вывод:** первый этаж самый дешевый, дорогой любой отличный от первого и последнего будет дороже.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Как в песне, "первый и последний этаж не предлагать". Традиционно, квартиры на первом и последнем этажах считаются самыми неудобными для жизни и это отражается на их стоимости.
# </div>

# %% [markdown]
# #### rooms

# %%
#медиана цены за квартиру в зависимости от кол-ва комнат
data_pivot = data.pivot_table(index='rooms', values='last_price')
data_pivot.index.names = ['кол-во комнат'] #переименовываем первый столбец-индекс
data_pivot.columns = data_pivot.columns.get_level_values(0) #сбрасываем мультииндекс
data_pivot.rename(columns={'last_price':'средняя цена'}, inplace=True) #переименовываем столбцы
display(data_pivot)
data_pivot.plot(y = 'средняя цена',kind = 'bar', figsize = (5,5), title = 'зависимость цены от кол-ва комнат')
plt.show()
# Out:
#                средняя цена
# кол-во комнат
# 0              2.923874e+06
# 1              3.687385e+06
# 2              4.752814e+06
# 3              5.613586e+06
# 4              6.197455e+06
# 5              6.612826e+06
# 6              7.321333e+06

# %% [markdown]
# **Вывод:** Чем больше комнат, тем квартира дороже.

# %% [markdown]
# #### weekday, month, year

# %%
#ф-я которая проходит по всем столбцам из созданного списка выше и создает на основе их значений создаст диаграмму
dd_column = ['weekday', 'month', 'year']
      
def data_hist(data,dd_column):
    for column in dd_column:
        (data.pivot_table(index=[column], values='last_price')
             .plot(grid=True, style='o-', figsize=(5, 5)))
        plt.title(column)
        plt.show()
        print()        
data_hist(data,dd_column)

# %% [markdown]
# **Вывод:**
# Дни недели: в среду кол-во выставленных объявлений дороже, в то время как в пятницу значительно дешевле.
# Месяцы: в апреле также выставляются максимальные в цене квартиры, в июне самые дешевые.
# Год: сильный упадок в цене 2016-2018 годах, дороже всего стоили квартиры в 2014 году. После 2018 цены вновь стали активно расти. Необходимо проверить дело только в цене или же в площади продаваемых квартир.

# %%
(data.pivot_table(index=['year'], values='total_area')
             .plot(grid=True, style='o-', figsize=(5, 5)))
plt.title('зависимость площади продажи от года')
plt.show()

# %% [markdown]
# После 2014 года стали продаваться квартиры с меньшей площадью. Посмотрим на взаимосвязь года продажи, площади и цены.

# %%
print(data[['total_area','year','last_price']].corr())
pd.plotting.scatter_matrix(data[['total_area','year','last_price']],figsize=(10,10))
plt.show()
# Out:
#             total_area      year  last_price
# total_area    1.000000 -0.051706    0.657033
# year         -0.051706  1.000000    0.015651
# last_price    0.657033  0.015651    1.000000

# %% [markdown]
# **Вывод:** Самая высоакая корреляция у цены с общей площадью. Видим, что при увеличении года, площадь продаваемых квартир уменьшалась, поэтому на графике зависимости цены от года продажи был такой резкий скачок вниз.

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
# Давай рассмотрим динамику цены и площади продаваемых квартир. И потом пересмотрим выводы, т.к., возможно, упала не столько цена, сколько площадь продаваемых квартир?
# </div>

# %% [markdown]
# **ОБЩИЙ ВЫВОД**

# %% [markdown]
# Необходимо было выполнить предобработку данных и изучить их, чтобы найти интересные особенности и зависимости, которые существуют на рынке недвижимости.
# Входные данные от Яндекс Недвижимости — архив объявлений за несколько лет о продаже квартир в Санкт-Петербурге и соседних населённых пунктах.
#
# В ходе аналитического исследования были выявлены следующие проблемы:
# - большое количество пропусков в данных (были выявлены и исправлены в ходе работы)
# - несоответствие значений и их типов данных (также изменены в ходе работы)
# - аномальные значения (сделан срез по верхней границе 3-го квартиля с учетом 1,5 размаха)
# - неявные дубликаты были выявлены в столбце 'locality_name'
# - выявлено влияние удаление от центра Санкт-Петербурга на цену квартиры с помощью гистограммы
# -
#
# Для получения итоговых выводов были проделаны следующие шаги:
# - выявлены топ 10 населенных пунктов по количеству объявлений о продаже, по данным поселениям был проведен расчет средней стоимости за кв м
# - проанализирована средняя скорость продаж путем визуализации и подсчета медианного значения (отбрасывая аномально долгие продажи и те объявления, которые еще не закрыты)
# - проведена графическая визуализация всех числовых показателей для определения самых популярных объявлений на сайте
# - проанализирована корреляция основных факторов, влияющих на общую стоимость и их взаимосвязь
#
# В среднем квартиры продаются за 75 дней
# Факторы, влияющие на стоимость: большое значение имееет площадь и соответственно кол-во комнат (корреляция у площади гораздо выше, соответственно не так важно кол-во комнат, как общий размер продаваемой квартиры), чем больше, тем соответственно дороже, также важно, чтобы квартира была не на первом и не на последнем этаже. В самом Санкт-Петербурге почти нет разницы, насколько квартира удалена от центра города, это не определяющий фактор. Дороже всего в топ-10 городах по объявлениям цена за кв м в Санкт-Петербурге, дешевле в Выборге.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Шикарный вывод и рекомендации для бизнеса. Кстати, хорошей практикой является написание в общем выводе всех твоих действий (кратко) по проекту. Ведь вывод раскрывает для заказчика всю твою проделанную работу и за что он платит деньги, даже если ему не интересен весь процесс исследования, то в отчёт он заглянет обязательно. Ты молодец!
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
# Комментарий от ревьюера №1 </b>
#
#
#
# У тебя получилась очень сильная и хорошая работа. Здорово, что расчеты ты сопровождаешь иллюстрациями, а так же не забываешь про комментарии, твой проект интересно проверять.
#
# ---
#
# Нужно поправить:
#
# 1) Шаг 4.1 (гистограммы по дню недели / месяцу)
#
# 2) Какие продажи можно считать быстрыми, а какие — необычно долгими?
#
# 3) Построить графики scatter
#
# 4) Корреляция Пирсона
#
# 5) Подправить выводы, после изменений
#
# ----
#
#
# Если у тебя будут какие-то вопросы по моим комментариям - обязательно пиши! Буду ждать работу на повторное ревью :)</div>
